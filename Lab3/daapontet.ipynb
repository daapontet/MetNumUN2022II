# %% [markdown]
# <a href="https://colab.research.google.com/github/daapontet/MetNumUN2022II/blob/main/Lab3/daapontet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **access to cognitive class diplomas:**
#
# https://www.linkedin.com/in/quimicodanielaponte/

# %% [markdown]
# ![daapontetcognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Python 101 for Data Science**
#
# https://courses.cognitiveclass.ai/certificates/2524edd1d2d5424b9faf232fb19a7300

# %% [markdown]
# ![foto data analysys.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Data Analysis with Python**
#
# https://courses.cognitiveclass.ai/certificates/f27b39d5ec7348e497bc2121cd76cf3c

# %% [markdown]
# ![data analysis with python.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Data Visualization with Python**
#
# https://courses.cognitiveclass.ai/certificates/957edec32a934d7ba01491a6ccdb8f84

# %% [markdown]
# ![Data_visualization.jpg](data:image/jpeg;base64,...)
